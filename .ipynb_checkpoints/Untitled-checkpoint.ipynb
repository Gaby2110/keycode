# %%
import sys
import random
class soul ():
    def __init__(self,name,hp,dfn,mana):
        self.name = name
        self.hp = hp
        self.dfn = dfn
        self.mana = mana
        
class monster(soul,object):  
    def def_monster():
        rand = random.randrange(1,4) 
        if rand == 1:
            return 1
        elif rand == 2:
            return 2 
        elif rand == 3:
            return 3
    
    def who_mons():
        if monster.def_monster() == 1:
            skeleton.name = "quiron"
            skeleton.hp = "100"
            skeleton.dfn = "10"
            skeleton.mana = "100"
            print("-----------------------------------")
            print (f"Hi i'm a monster and my name is {skeleton.name}")
            print (f"HP {skeleton.hp}")
            print (f"Defensa {skeleton.dfn}")
            print (f"Mana {skeleton.mana}")
            print("-----------------------------------")
        elif monster.def_monster() == 2:
            skeleton.name = "Quiron"
            skeleton.hp = "100"
            skeleton.dfn = "10"
            skeleton.mana = "100"
            print("-----------------------------------")
            print (f"Hi i'm a monster and my name is {skeleton.name}")
            print (f"HP {skeleton.hp}")
            print (f"Defensa {skeleton.dfn}")
            print (f"Mana {skeleton.mana}")
            print("-----------------------------------")
        elif monster.def_monster() == 3:
            skeleton.name = "prueba"
            skeleton.hp = "100"
            skeleton.dfn = "10"
            skeleton.mana = "100"
            print("-----------------------------------")
            print (f"Hi i'm a monster and my name is {skeleton.name}")
            print (f"HP {skeleton.hp}")
            print (f"Defensa {skeleton.dfn}")
            print (f"Mana {skeleton.mana}")
            print("-----------------------------------")
        
class skeleton(monster,object):     
    def attack(self,obj):
        print("-------------------------------------------- Monster attack---------------------------------------------")
        print ("I'm a skeleton and have two options of attack")
        print ('The first attack option is the chigiriki, have a power of 20 and the second one is the ono, have a power of 22')
        print("------------------------------------------------------------------------------------------------------------")
        if self.hp <= 0:
            print(f'{self.name} has already dead')
        else:
            if success():
                if obj.hp <= 0:
                    print(f'{obj.name} is dead')
                    sys.exit()
                else:
                    if obj.hp <= 0:
                        print(f'{obj.name} is dead') 
                        sys.exit()
                    else:
                        if self.mana == 0:
                            print("you don't have mana, lost turn")
                            self.mana == en
                        else:
                            if n == 1:
                                cm = 15
                                print(f'{self.name} attack to {obj.name} with an chigiriki')
                                self.mana = self.mana - cm
                                obj.hp = (obj.hp + obj.dfn) - 20
                                print(f"{obj.name}  actual HP: {obj.hp}")
                            elif n==2:
                                cm = 10
                                print(f'{self.name} attack to {obj.name} with an ono')
                                self.mana = self.mana - cm
                                obj.hp = (obj.hp + obj.dfn) - 22
                                print(f"{obj.name}  actual HP: {obj.hp}")
                            else:
                                print("This option attack doesn't exist")
            else:
                print(f"miss attack to {obj.name}")

# %%
monster.def_monster()
monster.who_mons()
# Out:
# -----------------------------------
# Hi i'm a monster and my name is chingiru
# HP 100
# Defensa 10
# Mana 100
# -----------------------------------
